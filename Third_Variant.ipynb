# %% [markdown]
# ### Architecture 3

# %% [markdown]
# ####  Train multiple classification architectures. At minimum, train and compare:
# ##### 3. Third architecture variant (e.g., a deeper custom CNN, a different pretrained backbone, or both feature-extraction and fine-tuning modes of the same backbone).

# %% [markdown]
# #### 1. Import Pre-Processed Data

# %%
# Import Pre-Processed Data

# %% [markdown]
# #### 2. Train Model

# %%
# Train Model

# %% [markdown]
# #### 3. Evaluate Model

# %%
# Evaluate Model
