# %% [markdown]
# ### Pre-processing Pipeline

# %% [markdown]
# ####   Prepare and preprocess your dataset. Build a per-identity training/validation/test split. Apply consistent image resizing, normalization, and any augmentation strategy you adopt (random crop, horizontal flip, color jitter). Document the preprocessing pipeline in a notebook or script.
